# %% [markdown]
# # Definir problema

# %% [markdown]
# Objetivo del Negocio: Identifica el problema que quieres resolver y cómo impacta al negocio. Ejemplos incluyen aumentar la retención de clientes, mejorar la eficiencia de un proceso o predecir ventas.
# KPIs (Indicadores Clave de Rendimiento): Define las métricas con las que medirás el éxito del proyecto. Estos pueden ser precisión, recall, AUC-ROC, etc., dependiendo del tipo de problema.

# %% [markdown]
# # Recopilación de Datos

# %% [markdown]
# Fuentes de Datos: Identifica las fuentes internas y externas de datos. Estos pueden provenir de bases de datos, APIs, web scraping, etc.
# Acceso y Seguridad: Asegúrate de tener acceso adecuado a los datos y sigue las normativas de privacidad y seguridad de datos (GDPR, etc.).
# Calidad de Datos: Verifica la calidad del dataset, su completitud, y la presencia de datos relevantes para el problema.

# %%
# Carga de librerías
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import warnings
import joblib

# Ignorar warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
#Carga Dataset
df = pd.read_csv('data.csv', sep=",")

# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)

# %% [markdown]
# Visualización: Utiliza herramientas como matplotlib, seaborn o plotly para identificar patrones y relaciones entre variables.
# Distribuciones y Correlaciones: Analiza distribuciones, correlaciones y posibles relaciones entre variables dependientes e independientes.
# Valores Atípicos y Faltantes: Identifica outliers y valores faltantes. Evalúa si deben eliminarse, imputarse o tratarse de alguna otra forma.

# %%
# Mostrar las primeras filas del dataset
print("Primeras filas del dataset:")
print(df.head())

# Mostrar información general del dataset
print("\nInformación del dataset:")
print(df.info())

# Descripción estadística básica del dataset
print("\nDescripción estadística:")
print(df.describe())

# Verificar si hay valores nulos en el dataset
print("\nValores nulos por columna:")
print(df.isnull().sum())
# Out:
# Primeras filas del dataset:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
# ...

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
info = df.shape
print("\nLa cantidad de filas y columnas en nuestro dataframe es de:",info)
# Out:
# La cantidad de filas y columnas en nuestro dataframe es de: (6607, 20)

# %%
tipos = df.dtypes
print("\nTipos de datos presentes en el dataset:\n",tipos)
# Out:
# Tipos de datos presentes en el dataset:
#  Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %% [markdown]
# ## Análisis de datos por variable

# %% [markdown]
# ### Análisis de Hours_Studied

# %%
# Descripción estadística básica de la variable 'Hours_Studied'
Hours_Studied_mean = np.mean(df['Hours_Studied'])
Hours_Studied_median = np.median(df['Hours_Studied'])
Hours_Studied_std = np.std(df['Hours_Studied'])
Hours_Studied_min = np.min(df['Hours_Studied'])
Hours_Studied_max = np.max(df['Hours_Studied'])

print("Análisis de la Variable 'Age'")
print(f"Media: {Hours_Studied_mean:.2f}")
print(f"Mediana: {Hours_Studied_median:.2f}")
print(f"Desviación Estándar: {Hours_Studied_std:.2f}")
print(f"Valor Mínimo: {Hours_Studied_min:.2f}")
print(f"Valor Máximo: {Hours_Studied_max:.2f}")

# Histograma
plt.figure(figsize=(10, 6))
sns.histplot(df['Hours_Studied'], bins=30, kde=True, color='#4C72B0')
plt.title('Distribución de Hours_Studied')
plt.xlabel('Hours_Studied')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# Análisis de la Variable 'Age'
# Media: 19.98
# Mediana: 20.00
# Desviación Estándar: 5.99
# Valor Mínimo: 1.00
# Valor Máximo: 44.00

# %% [markdown]
# ### Análisis de Attendance

# %%
# Descripción estadística básica de la variable 'Attendance'
Attendance_mean = np.mean(df['Attendance'])
Attendance_median = np.median(df['Attendance'])
Attendance_std = np.std(df['Attendance'])
Attendance_min = np.min(df['Attendance'])
Attendance_max = np.max(df['Attendance'])

print("Análisis de la Variable 'Age'")
print(f"Media: {Attendance_mean:.2f}")
print(f"Mediana: {Attendance_median:.2f}")
print(f"Desviación Estándar: {Attendance_std:.2f}")
print(f"Valor Mínimo: {Attendance_min:.2f}")
print(f"Valor Máximo: {Attendance_max:.2f}")

# Histograma
plt.figure(figsize=(10, 6))
sns.histplot(df['Attendance'], bins=30, kde=True, color='#4C72B0')
plt.title('Distribución de Attendance')
plt.xlabel('Attendance')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# Análisis de la Variable 'Age'
# Media: 79.98
# Mediana: 80.00
# Desviación Estándar: 11.55
# Valor Mínimo: 60.00
# Valor Máximo: 100.00

# %% [markdown]
# ### Análisis de Sleep_Hours

# %%
# Descripción estadística básica de la variable 'Sleep_Hours'
Sleep_Hours_mean = np.mean(df['Sleep_Hours'])
Sleep_Hours_median = np.median(df['Sleep_Hours'])
Sleep_Hours_std = np.std(df['Sleep_Hours'])
Sleep_Hours_min = np.min(df['Sleep_Hours'])
Sleep_Hours_max = np.max(df['Sleep_Hours'])

print("Análisis de la Variable 'Sleep_Hours'")
print(f"Media: {Sleep_Hours_mean:.2f}")
print(f"Mediana: {Sleep_Hours_median:.2f}")
print(f"Desviación Estándar: {Sleep_Hours_std:.2f}")
print(f"Valor Mínimo: {Sleep_Hours_min:.2f}")
print(f"Valor Máximo: {Sleep_Hours_max:.2f}")

# Histograma
plt.figure(figsize=(10, 6))
sns.histplot(df['Sleep_Hours'], bins=30, kde=True, color='#4C72B0')
plt.title('Distribución de Sleep_Hours')
plt.xlabel('Sleep_Hours')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# Análisis de la Variable 'Sleep_Hours'
# Media: 7.03
# Mediana: 7.00
# Desviación Estándar: 1.47
# Valor Mínimo: 4.00
# Valor Máximo: 10.00

# %% [markdown]
# ### Análisis de Previous_Scores

# %%
# Descripción estadística básica de la variable 'Sleep_Hours'
Previous_Scores_mean = np.mean(df['Previous_Scores'])
Previous_Scores_median = np.median(df['Previous_Scores'])
Previous_Scores_std = np.std(df['Previous_Scores'])
Previous_Scores_min = np.min(df['Previous_Scores'])
Previous_Scores_max = np.max(df['Previous_Scores'])

print("Análisis de la Variable 'Previous_Scores'")
print(f"Media: {Previous_Scores_mean:.2f}")
print(f"Mediana: {Previous_Scores_median:.2f}")
print(f"Desviación Estándar: {Previous_Scores_std:.2f}")
print(f"Valor Mínimo: {Previous_Scores_min:.2f}")
print(f"Valor Máximo: {Previous_Scores_max:.2f}")

# Histograma
plt.figure(figsize=(10, 6))
sns.histplot(df['Previous_Scores'], bins=30, kde=True, color='#4C72B0')
plt.title('Distribución de Previous_Scores')
plt.xlabel('Previous_Scores')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# Análisis de la Variable 'Previous_Scores'
# Media: 75.07
# Mediana: 75.00
# Desviación Estándar: 14.40
# Valor Mínimo: 50.00
# Valor Máximo: 100.00

# %% [markdown]
# # Limpieza y Preparación de Datos

# %% [markdown]
# Tratamiento de Nulos: Imputa o elimina valores nulos según corresponda.
# Normalización y Escalado: Si trabajas con modelos basados en distancias (p.ej., SVM o KNN), normaliza o escala las características.
# Creación de Nuevas Variables: Genera nuevas variables a partir de las existentes que puedan tener valor predictivo (feature engineering).
# Codificación de Variables Categóricas: Convierte variables categóricas a numéricas mediante técnicas como One-Hot Encoding o Label Encoding.

# %% [markdown]
# # Selección de Modelos

# %% [markdown]
# Establece una Línea Base: Comienza con un modelo simple, como Regresión Logística o Árboles de Decisión, para tener una referencia.
# Comparación de Modelos: Experimenta con modelos más complejos como Random Forest, Gradient Boosting, XGBoost, o modelos de Deep Learning si es necesario.
# Hiperparámetros: Optimiza los hiperparámetros utilizando técnicas como GridSearchCV o RandomizedSearchCV.

# %% [markdown]
# # Entrenamiento y Evaluación

# %% [markdown]
# División del Dataset: Divide los datos en conjuntos de entrenamiento, validación y prueba. (Por ejemplo, 70% entrenamiento, 15% validación, 15% prueba).
# Validación Cruzada: Usa técnicas de validación cruzada para reducir el overfitting y mejorar la generalización.
# Métricas de Evaluación: Evalúa el rendimiento de los modelos con métricas adecuadas. Si es un problema de clasificación, puedes usar precisión, recall, F1-score o AUC-ROC. Para regresión, RMSE o R².

# %% [markdown]
# # Interpretabilidad y Análisis de Resultados

# %% [markdown]
# Importancia de Características: Evalúa la importancia de cada variable en el modelo, ya sea mediante SHAP, LIME, o técnicas inherentes a los modelos como árboles de decisión.
# Errores y Anomalías: Analiza los errores del modelo para entender por qué falló en ciertas predicciones. Esto te puede guiar hacia mejoras en los datos o en el modelo.
# Bias y Fairness: Asegúrate de que el modelo no tiene sesgos inherentes y revisa que sea justo y ético en sus predicciones.

# %% [markdown]
# # Ajustes y Optimización

# %% [markdown]
# Tuning de Hiperparámetros: Realiza una búsqueda más exhaustiva de hiperparámetros si es necesario, o aplica técnicas como Bayesian Optimization.
# Ingeniería de Características Avanzada: Identifica más oportunidades para mejorar el desempeño del modelo mediante la creación o transformación de características.

# %% [markdown]
# # Despliegue del Modelo

# %% [markdown]
# Monitoreo en Producción: Sigue la evolución del modelo en producción. Verifica que no haya degradación en el rendimiento a lo largo del tiempo.
# Retraining: Define un pipeline de retraining si el modelo se enfrenta a datos que cambian con el tiempo (concept drift).
# Alertas: Configura alertas para detectar posibles fallos en la predicción o cambios drásticos en los datos.

# %% [markdown]
# # Comunicación de Resultados

# %% [markdown]
# Presentaciones: Prepara una presentación visualmente atractiva para comunicar los hallazgos clave, las decisiones de diseño y los resultados del modelo.
# Informes: Redacta un informe técnico que cubra desde la definición del problema hasta el despliegue del modelo y su monitoreo.

# %% [markdown]
# # Documentación

# %% [markdown]
# Documentación del Código: Asegúrate de que tu código esté bien documentado, con explicaciones claras sobre cómo interactuar con el modelo.
# Manual de Usuario: Si es necesario, escribe un manual para el equipo de desarrollo, stakeholders, o usuarios finales que interactuarán con el modelo.
